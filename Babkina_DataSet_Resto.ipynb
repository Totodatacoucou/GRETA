# %%
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
pd.read_csv('resto.csv')  
print ('resto est importé')
# Out:
# resto est importé

# %%
df=pd.read_csv('resto.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4622 entries, 0 to 4621
# Data columns (total 6 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Unnamed: 0          4622 non-null   int64
#  1   order_id            4622 non-null   int64
#  2   quantity            4622 non-null   int64
#  3   item_name           4622 non-null   object
#  4   choice_description  3376 non-null   object
#  5   item_price          4622 non-null   object
# dtypes: int64(3), object(3)
# memory usage: 216.8+ KB

# %%
df
# Out:
#       Unnamed: 0  order_id  quantity                              item_name  \
# 0              0         1         1           Chips and Fresh Tomato Salsa
# 1              1         1         1                                   Izze
# 2              2         1         1                       Nantucket Nectar
# 3              3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4              4         2         2                           Chicken Bowl
# ...          ...       ...       ...                                    ...
# 4617        4617      1833         1                          Steak Burrito
# 4618        4618      1833         1                          Steak Burrito
# 4619        4619      1834         1                     Chicken Salad Bowl
# 4620        4620      1834         1                     Chicken Salad Bowl
# 4621        4621      1834         1                     Chicken Salad Bowl
#
# ...

# %%
df.dtypes
# Out:
# Unnamed: 0             int64
# order_id               int64
# quantity               int64
# item_name             object
# choice_description    object
# item_price            object
# dtype: object

# %%
df.index
# Out:
# RangeIndex(start=0, stop=4622, step=1)

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'order_id', 'quantity', 'item_name', 'choice_description',
#        'item_price'],
#       dtype='object')

# %%
df.values
# Out:
# array([[0, 1, 1, 'Chips and Fresh Tomato Salsa', nan, '$2.39 '],
#        [1, 1, 1, 'Izze', '[Clementine]', '$3.39 '],
#        [2, 1, 1, 'Nantucket Nectar', '[Apple]', '$3.39 '],
#        ...,
#        [4619, 1834, 1, 'Chicken Salad Bowl',
#         '[Fresh Tomato Salsa, [Fajita Vegetables, Pinto Beans, Guacamole, Lettuce]]',
#         '$11.25 '],
#        [4620, 1834, 1, 'Chicken Salad Bowl',
#         '[Fresh Tomato Salsa, [Fajita Vegetables, Lettuce]]', '$8.75 '],
#        [4621, 1834, 1, 'Chicken Salad Bowl',
#         '[Fresh Tomato Salsa, [Fajita Vegetables, Pinto Beans, Lettuce]]',
#         '$8.75 ']], dtype=object)

# %%
df['item_price'] # voir prix dans le colonne des prix
# Out:
# 0        $2.39
# 1        $3.39
# 2        $3.39
# 3        $2.39
# 4       $16.98
#          ...
# 4617    $11.75
# 4618    $11.75
# 4619    $11.25
# 4620     $8.75
# 4621     $8.75
# Name: item_price, Length: 4622, dtype: object

# %%
df.describe() # on regarde la statistique des colonnes : valeur moyenne, STD, min, max, 
              #quantité des lignes par colonne
# Out:
#         Unnamed: 0     order_id     quantity
# count  4622.000000  4622.000000  4622.000000
# mean   2310.500000   927.254868     1.075725
# std    1334.400802   528.890796     0.410186
# min       0.000000     1.000000     1.000000
# 25%    1155.250000   477.250000     1.000000
# 50%    2310.500000   926.000000     1.000000
# 75%    3465.750000  1393.000000     1.000000
# max    4621.000000  1834.000000    15.000000

# %%
df
# Out:
#       Unnamed: 0  order_id  quantity                              item_name  \
# 0              0         1         1           Chips and Fresh Tomato Salsa
# 1              1         1         1                                   Izze
# 2              2         1         1                       Nantucket Nectar
# 3              3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4              4         2         2                           Chicken Bowl
# ...          ...       ...       ...                                    ...
# 4617        4617      1833         1                          Steak Burrito
# 4618        4618      1833         1                          Steak Burrito
# 4619        4619      1834         1                     Chicken Salad Bowl
# 4620        4620      1834         1                     Chicken Salad Bowl
# 4621        4621      1834         1                     Chicken Salad Bowl
#
# ...

# %%
sns.scatterplot(y=df.item_price, x=df.item_name) # voir corelation entre le prix et produitn, 
                                                 #probleme: pas lisible !
# Out:
# <AxesSubplot:xlabel='item_name', ylabel='item_price'>

# %%
sns.scatterplot(y=df.item_name, x=df.item_price)
# Out:
# <AxesSubplot:xlabel='item_price', ylabel='item_name'>

# %%
sns.set(style='whitegrid') # donner un style
sns.scatterplot(x="item_price",y="item_name",data=df) # une autre syntaxe
# Out:
# <AxesSubplot:xlabel='item_price', ylabel='item_name'>

# %%
#plt.figure(figsize=(7,7))
#sns.distplot(df.item_name);

# %%
df.item_price.describe() # on regarde colonne prix ( top ?)
# Out:
# count       4622
# unique        78
# top       $8.75
# freq         730
# Name: item_price, dtype: object

# %%
#sns.catplot(x='item_price', y='item_name', data=df, kind='box')

# %%
df2=df.sample(n=100)
print (df2)
# Out:
#       Unnamed: 0  order_id  quantity            item_name  \
# 2961        2961      1177         1          Canned Soda
# 3874        3874      1554         1         Chicken Bowl
# 2261        2261       911         1      Chicken Burrito
# 1279        1279       520         1    6 Pack Soft Drink
# 2715        2715      1077         1  Carnitas Soft Tacos
# ...          ...       ...       ...                  ...
# 3836        3836      1537         1    6 Pack Soft Drink
# 270          270       118         1      Chicken Burrito
# 1089        1089       449         1                Chips
# 2475        2475       982         1  Chips and Guacamole
# 4505        4505      1791         1                Chips
#
#                                      choice_description item_price
# 2961                                           [Sprite]     $1.09
# 3874  [Fresh Tomato Salsa, [Fajita Vegetables, Rice,...    $11.25
# 2261  [Roasted Chili Corn Salsa, [Rice, Black Beans,...     $8.75
# ...

# %%
df.head(5)
# Out:
#    Unnamed: 0  order_id  quantity                              item_name  \
# 0           0         1         1           Chips and Fresh Tomato Salsa
# 1           1         1         1                                   Izze
# 2           2         1         1                       Nantucket Nectar
# 3           3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4           4         2         2                           Chicken Bowl
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98

# %%
#g=sns.relplot(x="item_price", y="item_name", data=df, kind="line")
g=sns.relplot(x="item_name", y="item_price", data=df, kind="line")
plt.show()

# %%
g=sns.relplot(x="item_name", y="item_price", data=df2, kind="line")
plt.show()

# %%
df50=df.sample(n=50) # creation un nouveau data frame df50 de 50 elements aléatoires pour facilier la visualisation
#print (df50.head(5))
df50.head(5) # afichage que 5 premieres lignes et tous les colonnes
# Out:
#       Unnamed: 0  order_id  quantity       item_name  \
# 2803        2803      1113         1     Veggie Bowl
# 1570        1570       637         1    Chicken Bowl
# 467          467       200         1  Veggie Burrito
# 714          714       294         1  Veggie Burrito
# 2941        2941      1169         1      Steak Bowl
#
#                                      choice_description item_price
# 2803  [Fresh Tomato Salsa, [Fajita Vegetables, Rice,...    $11.25
# 1570  [Roasted Chili Corn Salsa, [Fajita Vegetables,...     $8.75
# 467   [Fresh Tomato Salsa (Mild), [Pinto Beans, Rice...     $8.49
# 714   [Fresh Tomato Salsa (Mild), [Pinto Beans, Rice...     $8.49
# 2941  [Roasted Chili Corn Salsa, [Rice, Cheese, Sour...    $11.75

# %%
g=sns.relplot(x="item_price", y="item_name", data=df50, kind="line", height=8, aspect=3) # 50 aléatoire
plt.show()

# %%
g=sns.relplot(x="item_price", y="item_name", data=df, kind="line", height=8, aspect=5)
plt.show()

# %%
#g=sns.relplot(x="item_price", y="item_name", data=df, kind="line", height=8, aspect=3)
g=sns.relplot(x="item_price", y="item_name", data=df, kind="line", height=8, aspect=2)
plt.show()

# %%
g=sns.relplot(x="item_price", y="item_name", data=df, kind="line", height=8, aspect=3)
#g=sns.relplot(x="item_price", y="item_name", data=df, kind="line", height=8, aspect=2)
plt.show()

# %%
df=df.sample(n=50)
df.head (5)
# Out:
#       Unnamed: 0  order_id  quantity           item_name  \
# 3305        3305      1325         1        Chicken Bowl
# 4422        4422      1763         1   Canned Soft Drink
# 202          202        90         1     Chicken Burrito
# 2686        2686      1067         1    Carnitas Burrito
# 4520        4520      1797         1  Chicken Salad Bowl
#
#                                      choice_description item_price
# 3305      [Fresh Tomato Salsa, [Rice, Cheese, Lettuce]]     $8.75
# 4422                                             [Coke]     $1.25
# 202   [Tomatillo Red Chili Salsa, [Rice, Black Beans...    $11.25
# 2686            [Fresh Tomato Salsa, [Cheese, Lettuce]]     $9.25
# 4520                      [Fresh Tomato Salsa, Lettuce]     $8.75

# %%
g=sns.catplot(x='item_price', y='item_name', data=df50, kind='box') # essaie de créer le diagramme type 
plt.show() #"boite à moustache", mais x et y sont des objets et non pas des chiffres (int) (float)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_14248\3856090409.py in <module>
# ----> 1 g=sns.catplot(x='item_price', y='item_name', data=df50, kind='box')
#       2 plt.show()
#
# ~\anaconda3\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ~\anaconda3\lib\site-packages\seaborn\categorical.py in catplot(x, y, hue, data, row, col, col_wrap, estimator, ci, n_boot, units, seed, order, hue_order, row_order, col_order, kind, height, aspect, orient, color, palette, legend, legend_out, sharex, sharey, margin_titles, facet_kws, **kwargs)
#    3790     p = _CategoricalPlotter()
#    3791     p.require_numeric = plotter_class.require_numeric
# ...

# %% [raw]
# il faut transformer 'item_price' et 'item_name' vers le floot (price) et int (name) je cherce comment faire, pas encore trouvé

# %%
df.item_price.describe()
# Out:
# count          50
# unique         15
# top       $11.25
# freq            8
# Name: item_price, dtype: object

# %%
df.item_name.describe()
# Out:
# count                      50
# unique                     21
# top       Chips and Guacamole
# freq                        8
# Name: item_name, dtype: object

# %%
g=sns.catplot(x='Unnamed: 0', y='quantity', data=df, kind='box') # 'Unnamed 0' quel type ? int?
plt.show() # boite à moustache 😂 .....  RIEN 😂😂

# %%
#df.Unnamed.describe()

# %%
df.Unnamed:0.describe() # marche pas à cause de "0"
# Out:
#   File "C:\Users\arnoa\AppData\Local\Temp\ipykernel_14248\132825962.py", line 1
#     df.Unnamed: 0.describe()
#                   ^
# SyntaxError: invalid syntax

# %%
df['Unnamed: 0'].head(5) # 'Unnamed: 0' type int ok
# Out:
# 3305    3305
# 4422    4422
# 202      202
# 2686    2686
# 4520    4520
# Name: Unnamed: 0, dtype: int64

# %%
#je veux transformer le type des elements dans les colonnes prix et noms pour povoir les traiter  
#df.item_price = df.item_price.replace(to_replace = ['type object'], value=[floot])
#df.head()

# %%
#df.astype({'item_price': int,'item_name': np.float64})

# %%
df.astype('item_price'.float64)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_14248\235327025.py in <module>
# ----> 1 df.astype('item_price'.float64)
#
# AttributeError: 'str' object has no attribute 'float64'
