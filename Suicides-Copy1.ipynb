# %%
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv("suicides.csv")
print('dataset loaded')
# Out:
# dataset loaded

# %%
df
# Out:
#              Pays  Année     F_H          Age  Suicides_no  Population  \
# 0         Albania   1987    male  15-24 years           21      312900
# 1         Albania   1987    male  35-54 years           16      308000
# 2         Albania   1987  female  15-24 years           14      289700
# 3         Albania   1987    male    75+ years            1       21800
# 4         Albania   1987    male  25-34 years            9      274300
# ...           ...    ...     ...          ...          ...         ...
# 27815  Uzbekistan   2014  female  35-54 years          107     3620833
# 27816  Uzbekistan   2014  female    75+ years            9      348465
# 27817  Uzbekistan   2014    male   5-14 years           60     2762158
# 27818  Uzbekistan   2014  female   5-14 years           44     2631600
# 27819  Uzbekistan   2014  female  55-74 years           21     1438935
#
#        Suicides/100k pop      Pays-année  HDI année PIB pays annuel $  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27820 entries, 0 to 27819
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Pays                27820 non-null  object
#  1   Année               27820 non-null  int64
#  2   F_H                 27820 non-null  object
#  3   Age                 27820 non-null  object
#  4   Suicides_no         27820 non-null  int64
#  5   Population          27820 non-null  int64
#  6   Suicides/100k pop   27820 non-null  float64
#  7   Pays-année          27820 non-null  object
#  8   HDI année           8364 non-null   float64
#  9   PIB pays annuel $   27820 non-null  object
#  10  PIB par habitant $  27820 non-null  int64
#  11  Generation          27820 non-null  object
# dtypes: float64(2), int64(4), object(6)
# memory usage: 2.5+ MB

# %%
df['Année']
# Out:
# 0        1987
# 1        1987
# 2        1987
# 3        1987
# 4        1987
#          ...
# 27815    2014
# 27816    2014
# 27817    2014
# 27818    2014
# 27819    2014
# Name: Année, Length: 27820, dtype: int64

# %%
df['Generation']
# Out:
# 0           Generation X
# 1                 Silent
# 2           Generation X
# 3        G.I. Generation
# 4                Boomers
#               ...
# 27815       Generation X
# 27816             Silent
# 27817       Generation Z
# 27818       Generation Z
# 27819            Boomers
# Name: Generation, Length: 27820, dtype: object

# %%
df[df['Generation']=='Silent']
# Out:
#              Pays  Année     F_H          Age  Suicides_no  Population  \
# 1         Albania   1987    male  35-54 years           16      308000
# 6         Albania   1987  female  35-54 years            6      278800
# 15        Albania   1988    male  35-54 years           14      314100
# 21        Albania   1988  female  35-54 years            4      284500
# 26        Albania   1989    male  35-54 years           15      318400
# ...           ...    ...     ...          ...          ...         ...
# 27794  Uzbekistan   2012  female    75+ years            4      338557
# 27801  Uzbekistan   2013    male    75+ years           13      221002
# 27804  Uzbekistan   2013  female    75+ years            8      345180
# 27813  Uzbekistan   2014    male    75+ years           17      224995
# 27816  Uzbekistan   2014  female    75+ years            9      348465
#
#        Suicides/100k pop      Pays-année  HDI année PIB pays annuel $  \
# ...

# %%
# Out:
#         Pays  Année     F_H          Age  Suicides_no  Population  \
# 9086  France   1985    male    75+ years         1522     1263200
# 9087  France   1985    male  55-74 years         2363     4471600
# 9088  France   1985    male  35-54 years         2752     6799400
# 9089  France   1985    male  25-34 years         1492     4240100
# 9090  France   1985  female    75+ years          670     2434600
# ...      ...    ...     ...          ...          ...         ...
# 9441  France   2014    male  15-24 years          282     3841223
# 9442  France   2014  female  25-34 years          170     3985618
# 9443  France   2014  female  15-24 years           92     3711936
# 9444  France   2014    male   5-14 years           14     4069116
# 9445  France   2014  female   5-14 years           12     3878553
#
#       Suicides/100k pop  Pays-année  HDI année  PIB pays annuel $  \
# 9086             120.49  France1985      0.741    553,138,414,367
# ...

# %%
df_France=df[df['Pays']=='France']
df_France
# Out:
#         Pays  Année     F_H          Age  Suicides_no  Population  \
# 9086  France   1985    male    75+ years         1522     1263200
# 9087  France   1985    male  55-74 years         2363     4471600
# 9088  France   1985    male  35-54 years         2752     6799400
# 9089  France   1985    male  25-34 years         1492     4240100
# 9090  France   1985  female    75+ years          670     2434600
# ...      ...    ...     ...          ...          ...         ...
# 9441  France   2014    male  15-24 years          282     3841223
# 9442  France   2014  female  25-34 years          170     3985618
# 9443  France   2014  female  15-24 years           92     3711936
# 9444  France   2014    male   5-14 years           14     4069116
# 9445  France   2014  female   5-14 years           12     3878553
#
#       Suicides/100k pop  Pays-année  HDI année  PIB pays annuel $  \
# 9086             120.49  France1985      0.741    553,138,414,367
# ...

# %%
df = sns.catplot(x="Année", y="Generation", data=df, kind="box")
plt.show()

# %%
sns.relplot(x='Age', y='F_H', data=df, kind='line')
plt.show()

# %%
sns.relplot(x="Age", y="F_H", data = df.sample(35), kind="line", height=8, aspect=3)

# %%
f, ax = plt.subplots(figsize=(28,6))
sns.relplot(x="F_H", y="Suicides/100k pop", data =df, kind="line", ax = ax)
plt.close(2)
# Out:
# C:\Users\arnoa\anaconda3\lib\site-packages\seaborn\relational.py:943: UserWarning: relplot is a figure-level function and does not accept the `ax` parameter. You may wish to try lineplot
#   warnings.warn(msg, UserWarning)

# %%
sns.relplot(x='F_H', y='Suicides/100k pop', data=df, kind='line')
plt.show()

# %%
# Voir quatnité des suisides pour 100 000 pers  
#plt.subplots(figsize=(20,6))
sns.relplot(x='Année', y='Suicides/100k pop', data=df, kind='line')
plt.show()

# %%
#Albania hoomes 
#df = df[(df["Pays"].str.contains("Albania")) & (df["F_H"].str.contains("male"))]
#plt.subplots(figsize=(20,6))
#sns.lineplot(x="Année", y="Age", data=df, label='année_age')
#sns.lineplot(x="Année", y="Generation", data=df, label='année_generation')
#sns.lineplot(x="Année", y="PIB par habitant $", data=df, label='PIB par habitant $')
#plt.show()

# %%
#Voir PIB par habitan 
plt.subplots(figsize=(20,6))
sns.lineplot(x="Année", y="PIB par habitant $", data=df, label='PIB par habitant $')
plt.show()

# %%
sns.lineplot(x="Année", y="Suicides/100k pop", data=df, label='corelation anée et suisides')
plt.show()

# %%
sns.scatterplot(data=df, x="Année", y="Population", hue="Age")
# Out:
# <AxesSubplot:xlabel='Année', ylabel='Population'>

# %%
sns.scatterplot(data=df, x="Année", y="Population", hue="F_H")
# Out:
# <AxesSubplot:xlabel='Année', ylabel='Population'>

# %%
plt.subplots(figsize=(20,6))
sns.lineplot(x="Année", y="Generation", data=df, label='Generation & Année')
plt.show()

# %%
#ns.relplot(x='LotArea', y='SalePrice', data=df)

# %%
#df['Pays']="France"

# %%
df.Pays
# Out:
# 0           Albania
# 1           Albania
# 2           Albania
# 3           Albania
# 4           Albania
#             ...
# 27815    Uzbekistan
# 27816    Uzbekistan
# 27817    Uzbekistan
# 27818    Uzbekistan
# 27819    Uzbekistan
# Name: Pays, Length: 27820, dtype: object

# %%
df[df['Generation']=='Silent']
# Out:
#              Pays  Année     F_H          Age  Suicides_no  Population  \
# 1         Albania   1987    male  35-54 years           16      308000
# 6         Albania   1987  female  35-54 years            6      278800
# 15        Albania   1988    male  35-54 years           14      314100
# 21        Albania   1988  female  35-54 years            4      284500
# 26        Albania   1989    male  35-54 years           15      318400
# ...           ...    ...     ...          ...          ...         ...
# 27794  Uzbekistan   2012  female    75+ years            4      338557
# 27801  Uzbekistan   2013    male    75+ years           13      221002
# 27804  Uzbekistan   2013  female    75+ years            8      345180
# 27813  Uzbekistan   2014    male    75+ years           17      224995
# 27816  Uzbekistan   2014  female    75+ years            9      348465
#
#        Suicides/100k pop      Pays-année  HDI année PIB pays annuel $  \
# ...

# %%
sns.heatmap(data =df.corr(),cmap = 'magma', annot = True)
# Out:
# <AxesSubplot:>

# %%
df_men = df[df.F_H == "male"]
df_women = df[df.F_H == "female"]
sns.lineplot(df_men.Année, df.Suicides_no, ci = None)
sns.lineplot(df_women.Année, df.Suicides_no, ci = None)
plt.legend(["male", 'female'])
plt.show()
# Out:
# C:\Users\arnoa\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\arnoa\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
df_Age = df.groupby(["Année","Age"])["Suicides_no", "Population"].sum()
df_reset = df_age.copy().reset_index()
plt.figure(figsize=(10,6))
sns.lineplot("Année", df_reset.Suicides_no*100/df_reset.Population, hue = "Age",
             data = df_reset, linewidth = 2.5, style = "Age", markers=True
            , dashes=False)
plt.xticks(rotation = 90)
plt.show()
# Out:
# C:\Users\arnoa\AppData\Local\Temp\ipykernel_8372\3507580743.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df_Age = df.groupby(["Année","Age"])["Suicides_no", "Population"].sum()
# C:\Users\arnoa\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
print(df.columns)
# Out:
# Index(['Pays', 'Année', 'F_H', 'Age', 'Suicides_no', 'Population',
#        'Suicides/100k pop', 'Pays-année', 'HDI année', 'PIB pays annuel $',
#        'PIB par habitant $', 'Generation'],
#       dtype='object')

# %%
df_Generation = df.groupby(["Année", "Generation"])["Suicides_no", "Population"].sum()
df_Generation_reset = df_Generation.copy().reset_index()
plt.figure(figsize=(9,6))
sns.lineplot("Année", df_Generation_reset.Suicides_no*100/df_Generation_reset.Population, hue = "Generation", 
            data = df_Generation_reset, linewidth = 2.5, style = "Generation", markers=True
            , dashes=False)
plt.xticks(rotation = 90)
plt.show()
# Out:
# C:\Users\arnoa\AppData\Local\Temp\ipykernel_8372\527548893.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df_Generation = df.groupby(["Année", "Generation"])["Suicides_no", "Population"].sum()
# C:\Users\arnoa\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
#sns.heatmap(data =df.corr(),cmap = 'magma', annot = True)

# %%
df1 = df.groupby("Pays")["Suicides_no"].sum()
Pays_name = list(df1.index.get_level_values(0))
len(Pays_name)
# Out:
# 101

# %%
df1
# Out:
# Pays
# Turkmenistan                8624
# Albania                     1970
# Singapore                  10089
# Hungary                    73891
# Colombia                   53080
# Cabo Verde                    42
# New Zealand                14383
# South Africa                7321
# Uruguay                    13138
# Brazil                    226613
# Antigua and Barbuda           11
# Grenada                       38
# Czech Republic             43687
# Kyrgyzstan                 13090
# Azerbaijan                  1656
# Oman                          33
# Philippines                21330
# Sweden                     37795
# Bosnia and Herzegovina       318
# Saint Lucia                  230
# United Kingdom            136805
# Germany                   291262
# Bahamas                       93
# Bulgaria                   36388
# Suriname                    2166
# Latvia                     12770
# Ecuador                    20660
# Mongolia                     423
# ...

# %%
df1 = df1.sample(50)
print (df1.sample(50))
# Out:
# Pays
# Slovenia                   10615
# Cabo Verde                    42
# New Zealand                14383
# Mauritius                   3894
# Austria                    50073
# Philippines                21330
# Oman                          33
# Paraguay                    4783
# Saint Lucia                  230
# Kyrgyzstan                 13090
# Portugal                   24061
# El Salvador                11683
# Colombia                   53080
# United Kingdom            136805
# Uruguay                    13138
# Hungary                    73891
# Bahamas                       93
# Ecuador                    20660
# Bahrain                      463
# Costa Rica                  6792
# Estonia                     7034
# Switzerland                26217
# Nicaragua                   2013
# Singapore                  10089
# Azerbaijan                  1656
# Qatar                        574
# Mexico                    111139
# Georgia                     3224
# ...

# %%
df_Pays_100k = df.groupby('Pays').agg({'Suicides_no': "sum"}).reset_index().sort_values('Suicides_no', ascending = False)
df_Pays_100k.head(20)
# Out:
#                   Pays  Suicides_no
# 75  Russian Federation      1209742
# 98       United States      1034013
# 46               Japan       806902
# 33              France       329127
# 95             Ukraine       319950
# 35             Germany       291262
# 73   Republic of Korea       261730
# 15              Brazil       226613
# 69              Poland       139098
# 97      United Kingdom       136805
# 44               Italy       132060
# 58              Mexico       111139
# 91            Thailand       110643
# 18              Canada       107561
# 47          Kazakhstan       101546
# 86               Spain       100202
# 2            Argentina        82219
# 40             Hungary        73891
# 74             Romania        72777
# 5            Australia        70111

# %%
plt.figure(figsize=(8,32))
sns.barplot(data = df,x =df["Suicides_no"], y = df['Pays'], orient='horizonal', dodge=True)
plt.show()

# %%
sns.barplot(data=df, x="Suicides_no", y="Age", hue="F_H")
# Out:
# <AxesSubplot:xlabel='Suicides_no', ylabel='Age'>

# %%
sns.barplot(data=df, x="Suicides_no", y="Pays", hue="F_H")
# Out:
# <AxesSubplot:xlabel='Suicides_no', ylabel='Pays'>

# %%
sns.barplot(data=df, x="Suicides_no", y="Generation", hue="F_H")
# Out:
# <AxesSubplot:xlabel='Suicides_no', ylabel='Generation'>

# %%
sns.barplot(data=df, x="Suicides_no", y="PIB par habitant $", hue="F_H")
# Out:
# <AxesSubplot:xlabel='Suicides_no', ylabel='PIB par habitant $'>

# %%
df_France
sns.barplot(data=df_France, x="Suicides_no", y="PIB par habitant $", hue="F_H")
# Out:
# <AxesSubplot:xlabel='Suicides_no', ylabel='PIB par habitant $'>

# %% [markdown]
# # FRANCE

# %%
df_France
sns.barplot(data=df_France, x="Suicides_no", y="Age", hue="F_H")
# Out:
# <AxesSubplot:xlabel='Suicides_no', ylabel='Age'>

# %%
sns.scatterplot(data=df_France, x="Année", y="Population", hue="F_H")
# Out:
# <AxesSubplot:xlabel='Année', ylabel='Population'>

# %% [raw]
# df_Russie
# df_France=df[df['Pays']=='France']
# df_France
# sns.barplot(data=df, x="Suicides_no", y="Pays", hue="F_H")

# %%
#sns.barplot(data=df, x="Suicides_no", y="df[df['Pays']=='France']", hue="F_H")

# %% [markdown]
# # USA

# %%
df_United_States=df[df['Pays']=='United States']

# %%
sns.barplot(data=df_United_States, x="Suicides_no", y="Age", hue="F_H")
# Out:
# <AxesSubplot:xlabel='Suicides_no', ylabel='Age'>

# %%
![image.png](attachment:image.png)
# Out:
# '[image.png]' n’est pas reconnu en tant que commande interne
# ou externe, un programme exécutable ou un fichier de commandes.

# %% [markdown]
# # RUSSIE

# %%
df_Russie=df[df['Pays']=='Russian Federation']

# %%
sns.barplot(data=df_Russie, x="Suicides_no", y="Age", hue="F_H")
# Out:
# <AxesSubplot:xlabel='Suicides_no', ylabel='Age'>
